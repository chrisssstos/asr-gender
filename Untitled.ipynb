# %%
# %run dataset-preparation.py
# Out:
# Copying files...
# Progress: 7442/7442
# Splitting into train and test
#
# Done!

# %%
# %run train.py
# Out:
# Starting training
# Analyzing file 1 of 890: dataset/train/anger\1001_DFA_ANG_XX.wav
# Analyzing file 2 of 890: dataset/train/anger\1001_IEO_ANG_HI.wav
# Analyzing file 3 of 890: dataset/train/anger\1001_IOM_ANG_XX.wav
# Analyzing file 4 of 890: dataset/train/anger\1001_ITS_ANG_XX.wav
# Analyzing file 5 of 890: dataset/train/anger\1001_IWL_ANG_XX.wav
# Analyzing file 6 of 890: dataset/train/anger\1001_IWW_ANG_XX.wav
# Analyzing file 7 of 890: dataset/train/anger\1001_MTI_ANG_XX.wav
# Analyzing file 8 of 890: dataset/train/anger\1001_TAI_ANG_XX.wav
# Analyzing file 9 of 890: dataset/train/anger\1001_TIE_ANG_XX.wav
# Analyzing file 10 of 890: dataset/train/anger\1001_TSI_ANG_XX.wav
# Analyzing file 11 of 890: dataset/train/anger\1001_WSI_ANG_XX.wav
# Analyzing file 12 of 890: dataset/train/anger\1002_IEO_ANG_MD.wav
# Analyzing file 13 of 890: dataset/train/anger\1002_IOM_ANG_XX.wav
# Analyzing file 14 of 890: dataset/train/anger\1002_ITH_ANG_XX.wav
# ...

# %%
pip install plotly
# Out:
# ...
#      ---------------------------------------- 15.6/15.6 MB 5.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run test_single_file.py
# Out:
# fileClassification: wav file not found!
# (-1, -1, -1)
